# %% [markdown]
# <a href="https://colab.research.google.com/github/Dorra2021/Random_Forest/blob/main/Car_Evaluation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import os
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
os.chdir('/content/drive/My Drive')
df=pd.read_csv('car_evaluation.csv',sep=',',  header=None)

# %%
df
# Out:
#           0      1      2     3      4     5      6
# 0     vhigh  vhigh      2     2  small   low  unacc
# 1     vhigh  vhigh      2     2  small   med  unacc
# 2     vhigh  vhigh      2     2  small  high  unacc
# 3     vhigh  vhigh      2     2    med   low  unacc
# 4     vhigh  vhigh      2     2    med   med  unacc
# ...     ...    ...    ...   ...    ...   ...    ...
# 1723    low    low  5more  more    med   med   good
# 1724    low    low  5more  more    med  high  vgood
# 1725    low    low  5more  more    big   low  unacc
# 1726    low    low  5more  more    big   med   good
# 1727    low    low  5more  more    big  high  vgood
#
# [1728 rows x 7 columns]

# %%
df.columns=["buying","maintenance","doors","persons","luggage","safety","decision"]

# %%
df
# Out:
#      buying maintenance  doors persons luggage safety decision
# 0     vhigh       vhigh      2       2   small    low    unacc
# 1     vhigh       vhigh      2       2   small    med    unacc
# 2     vhigh       vhigh      2       2   small   high    unacc
# 3     vhigh       vhigh      2       2     med    low    unacc
# 4     vhigh       vhigh      2       2     med    med    unacc
# ...     ...         ...    ...     ...     ...    ...      ...
# 1723    low         low  5more    more     med    med     good
# 1724    low         low  5more    more     med   high    vgood
# 1725    low         low  5more    more     big    low    unacc
# 1726    low         low  5more    more     big    med     good
# 1727    low         low  5more    more     big   high    vgood
#
# [1728 rows x 7 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1728 entries, 0 to 1727
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   buying       1728 non-null   object
#  1   maintenance  1728 non-null   object
#  2   doors        1728 non-null   object
#  3   persons      1728 non-null   object
#  4   luggage      1728 non-null   object
#  5   safety       1728 non-null   object
#  6   decision     1728 non-null   object
# dtypes: object(7)
# memory usage: 94.6+ KB

# %%
df.shape
# Out:
# (1728, 7)

# %%
df.columns
# Out:
# Index(['buying', 'maintenance', 'doors', 'persons', 'luggage', 'safety',
#        'decision'],
#       dtype='object')

# %%
for colonne in df.columns:
  print(colonne)
# Out:
# buying
# maintenance
# doors
# persons
# luggage
# safety
# decision

# %%
for colonne in df.columns:
  print("la colonne est" , colonne)
  print(df[colonne].value_counts())
# Out:
# la colonne est buying
# vhigh    432
# high     432
# med      432
# low      432
# Name: buying, dtype: int64
# la colonne est maintenance
# vhigh    432
# high     432
# med      432
# low      432
# Name: maintenance, dtype: int64
# la colonne est doors
# 2        432
# 3        432
# 4        432
# 5more    432
# Name: doors, dtype: int64
# la colonne est persons
# 2       576
# 4       576
# more    576
# Name: persons, dtype: int64
# la colonne est luggage
# small    576
# med      576
# big      576
# Name: luggage, dtype: int64
# la colonne est safety
# low     576
# med     576
# high    576
# Name: safety, dtype: int64
# la colonne est decision
# unacc    1210
# acc       384
# good       69
# vgood      65
# Name: decision, dtype: int64

# %%
df.columns
# Out:
# Index(['buying', 'maintenance', 'doors', 'persons', 'luggage', 'safety',
#        'decision'],
#       dtype='object')

# %%
df.dtypes
# Out:
# buying         object
# maintenance    object
# doors          object
# persons        object
# luggage        object
# safety         object
# decision       object
# dtype: object

# %%
df
# Out:
#      buying maintenance  doors persons luggage safety decision
# 0     vhigh       vhigh      2       2   small    low    unacc
# 1     vhigh       vhigh      2       2   small    med    unacc
# 2     vhigh       vhigh      2       2   small   high    unacc
# 3     vhigh       vhigh      2       2     med    low    unacc
# 4     vhigh       vhigh      2       2     med    med    unacc
# ...     ...         ...    ...     ...     ...    ...      ...
# 1723    low         low  5more    more     med    med     good
# 1724    low         low  5more    more     med   high    vgood
# 1725    low         low  5more    more     big    low    unacc
# 1726    low         low  5more    more     big    med     good
# 1727    low         low  5more    more     big   high    vgood
#
# [1728 rows x 7 columns]

# %%
df.isnull().sum()
# Out:
# buying         0
# maintenance    0
# doors          0
# persons        0
# luggage        0
# safety         0
# decision       0
# dtype: int64

# %% [markdown]
# Visualisation:

# %%
df.columns
# Out:
# Index(['buying', 'maintenance', 'doors', 'persons', 'luggage', 'safety',
#        'decision'],
#       dtype='object')

# %% [markdown]
# Declare feature vector and target variable:

# %% [markdown]
# Label Encoder pour les données catégorielles :

# %%
df
# Out:
#      buying maintenance  doors persons luggage safety decision
# 0     vhigh       vhigh      2       2   small    low    unacc
# 1     vhigh       vhigh      2       2   small    med    unacc
# 2     vhigh       vhigh      2       2   small   high    unacc
# 3     vhigh       vhigh      2       2     med    low    unacc
# 4     vhigh       vhigh      2       2     med    med    unacc
# ...     ...         ...    ...     ...     ...    ...      ...
# 1723    low         low  5more    more     med    med     good
# 1724    low         low  5more    more     med   high    vgood
# 1725    low         low  5more    more     big    low    unacc
# 1726    low         low  5more    more     big    med     good
# 1727    low         low  5more    more     big   high    vgood
#
# [1728 rows x 7 columns]

# %%
df.dtypes
# Out:
# buying         object
# maintenance    object
# doors          object
# persons        object
# luggage        object
# safety         object
# decision       object
# dtype: object

# %% [markdown]
# Codage Ordinal: pour les variables catégorielles. L'encodage ordinal est une technique similaire au Label Encoder, mais avec une distinction importante. Il permet de spécifier explicitement l'ordre des catégories et attribue des valeurs numériques en fonction de cet ordre.

# %%
from matplotlib import axis
X=df.drop(labels="decision", axis=1)
y=df['decision']

# %%
le = LabelEncoder()

# %%
df.columns
# Out:
# Index(['buying', 'maintenance', 'doors', 'persons', 'luggage', 'safety',
#        'decision'],
#       dtype='object')

# %%
le = LabelEncoder()

# %%
df.columns
# Out:
# Index(['buying', 'maintenance', 'doors', 'persons', 'luggage', 'safety',
#        'decision'],
#       dtype='object')

# %% [markdown]
# Apply label encoer for multiple columns

# %%
#df[['buying', 'maintenance', 'doors', 'persons', 'luggage', 'safety']] = df[['buying', 'maintenance', 'doors', 'persons', 'luggage', 'safety']].apply(LabelEncoder().fit_transform)

# %%
#df

# %%
X=X.apply(LabelEncoder().fit_transform)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.33, random_state = 42)

# %%
X_train.shape, X_test.shape
# Out:
# ((1157, 6), (571, 6))

# %% [markdown]
# Random Forest Model (default parameters)

# %%
from sklearn.ensemble import RandomForestClassifier
rfc = RandomForestClassifier(random_state=0)
rfc.fit(X_train, y_train)

# Predict the Test set results

y_pred = rfc.predict(X_test)

# %%
# Check accuracy score

from sklearn.metrics import accuracy_score

print('Model accuracy score with 10 decision-trees : {0:0.4f}'. format(accuracy_score(y_test, y_pred)))
# Out:
# Model accuracy score with 10 decision-trees : 0.9545
